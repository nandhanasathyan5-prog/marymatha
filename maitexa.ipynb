# %% [markdown]
# <a href="https://colab.research.google.com/github/nandhanasathyan5-prog/marymatha/blob/main/maitexa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/Msc 24-26 /fraudTest.csv')
df
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 0               0   2020-06-21 12:14:25     2291163933867244
# 1               1   2020-06-21 12:14:33     3573030041201292
# 2               2   2020-06-21 12:14:53     3598215285024754
# 3               3   2020-06-21 12:15:15     3591919803438423
# 4               4   2020-06-21 12:15:17     3526826139003047
# ...           ...                   ...                  ...
# 11692       11692   2020-06-24 22:21:35  4653178848915023204
# 11693       11693   2020-06-24 22:22:53        4681699462969
# 11694       11694   2020-06-24 22:23:44     4003989662068504
# 11695       11695   2020-06-24 22:24:26         639046421587
# 11696       11696   2020-06-24 22:24:58     6011367958204270
#
#                                    merchant        category    amt   first  \
# 0                     fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                      fraud_Sporer-Keebler   personal_care  29.84  Joanne
# ...

# %%
df1=pd.read_csv('/content/drive/MyDrive/Msc 24-26 /fraudTrain.csv')
df1
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 0               0   2019-01-01 00:00:18     2703186189652095
# 1               1   2019-01-01 00:00:44         630423337322
# 2               2   2019-01-01 00:00:51       38859492057661
# 3               3   2019-01-01 00:01:16     3534093764340240
# 4               4   2019-01-01 00:03:06      375534208663984
# ...           ...                   ...                  ...
# 15588       15588   2019-01-10 00:19:11     4836998673805450
# 15589       15589   2019-01-10 00:20:34     6538891242532018
# 15590       15590   2019-01-10 00:21:08     6011603272871604
# 15591       15591   2019-01-10 00:21:25  4210078554961359092
# 15592       15592   2019-01-10 00:22:39     6011329966782895
#
#                                      merchant       category     amt  \
# 0                  fraud_Rippin, Kub and Mann       misc_net    4.97
# 1             fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 11692       11692   2020-06-24 22:21:35  4653178848915023204
# 11693       11693   2020-06-24 22:22:53        4681699462969
# 11694       11694   2020-06-24 22:23:44     4003989662068504
# 11695       11695   2020-06-24 22:24:26         639046421587
# 11696       11696   2020-06-24 22:24:58     6011367958204270
#
#                               merchant        category    amt   first  \
# 11692                  fraud_Beier LLC   entertainment  11.58  Robert
# 11693  fraud_Willms, Kris and Bergnaum    shopping_pos   9.84  Joseph
# 11694           fraud_Torphy-Kertzmann  health_fitness  37.98   Chris
# 11695              fraud_Abbott-Rogahn   entertainment  75.39   Dylan
# 11696             fraud_Torphy-Goyette    shopping_pos   8.37   Tammy
#
#            last gender                        street  ...      lat     long  \
# 11692      Hall      M   371 Anthony Trail Suite 354  ...  36.7779 -81.7676
# ...

# %%
df.isnull()
# Out:
#        Unnamed: 0  trans_date_trans_time  cc_num  merchant  category    amt  \
# 0           False                  False   False     False     False  False
# 1           False                  False   False     False     False  False
# 2           False                  False   False     False     False  False
# 3           False                  False   False     False     False  False
# 4           False                  False   False     False     False  False
# ...           ...                    ...     ...       ...       ...    ...
# 11692       False                  False   False     False     False  False
# 11693       False                  False   False     False     False  False
# 11694       False                  False   False     False     False  False
# 11695       False                  False   False     False     False  False
# 11696       False                  False   False     False     False  False
#
# ...

# %%
df.isna().any()
# Out:
# Unnamed: 0               False
# trans_date_trans_time    False
# cc_num                   False
# merchant                 False
# category                 False
# amt                      False
# first                    False
# last                     False
# gender                   False
# street                   False
# city                     False
# state                    False
# zip                      False
# lat                      False
# long                     False
# city_pop                 False
# job                      False
# dob                      False
# trans_num                False
# unix_time                 True
# merch_lat                 True
# merch_long                True
# is_fraud                  True
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11697 entries, 0 to 11696
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             11697 non-null  int64
#  1   trans_date_trans_time  11697 non-null  object
#  2   cc_num                 11697 non-null  int64
#  3   merchant               11697 non-null  object
#  4   category               11697 non-null  object
#  5   amt                    11697 non-null  float64
#  6   first                  11697 non-null  object
#  7   last                   11697 non-null  object
#  8   gender                 11697 non-null  object
#  9   street                 11697 non-null  object
#  10  city                   11697 non-null  object
#  11  state                  11697 non-null  object
#  12  zip                    11697 non-null  int64
#  13  lat                    11697 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  11697.000000  1.169700e+04  11697.000000  11697.000000  11697.000000
# mean    5848.000000  4.065538e+17     66.241288  48583.520988     38.491370
# std     3376.777384  1.295805e+18    124.015784  26706.800199      5.112304
# min        0.000000  6.041621e+10      1.000000   1257.000000     20.027100
# 25%     2924.000000  1.800429e+14      9.200000  26237.000000     34.509100
# 50%     5848.000000  3.518669e+15     43.770000  48034.000000     39.342600
# 75%     8772.000000  4.634956e+15     79.770000  72011.000000     42.014400
# max    11696.000000  4.992346e+18   3396.840000  99783.000000     65.689900
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  11697.000000  1.169700e+04  1.169600e+04  11696.000000  11696.000000
# mean     -90.029371  9.471794e+04  1.371949e+09     38.477973    -90.028840
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                float64
# merch_lat                float64
# merch_long               float64
# is_fraud                 float64
# dtype: object

# %%
# removing duplicate rows

df=df.drop_duplicates()
df
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 0               0   2020-06-21 12:14:25     2291163933867244
# 1               1   2020-06-21 12:14:33     3573030041201292
# 2               2   2020-06-21 12:14:53     3598215285024754
# 3               3   2020-06-21 12:15:15     3591919803438423
# 4               4   2020-06-21 12:15:17     3526826139003047
# ...           ...                   ...                  ...
# 11692       11692   2020-06-24 22:21:35  4653178848915023204
# 11693       11693   2020-06-24 22:22:53        4681699462969
# 11694       11694   2020-06-24 22:23:44     4003989662068504
# 11695       11695   2020-06-24 22:24:26         639046421587
# 11696       11696   2020-06-24 22:24:58     6011367958204270
#
#                                    merchant        category    amt   first  \
# 0                     fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                      fraud_Sporer-Keebler   personal_care  29.84  Joanne
# ...

# %%
df.shape
# Out:
# (11697, 23)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.isna().any()
# Out:
# Unnamed: 0               False
# trans_date_trans_time    False
# cc_num                   False
# merchant                 False
# category                 False
# amt                      False
# first                    False
# last                     False
# gender                   False
# street                   False
# city                     False
# state                    False
# zip                      False
# lat                      False
# long                     False
# city_pop                 False
# job                      False
# dob                      False
# trans_num                False
# unix_time                 True
# merch_lat                 True
# merch_long                True
# is_fraud                  True
# dtype: bool

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df.shape
# Out:
# (11696, 23)

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(20,15),bins=50,edgecolor='k')
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df['is_fraud'].value_counts()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
fig,x=plt.subplots(figsize=(10,5))
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(),annot=True,linewidth=0.5,ax=x)
plt.show()

# %%
numerical_df = df.select_dtypes(include=np.number)
numerical_df.head()
# Out:
#    Unnamed: 0            cc_num    amt    zip      lat      long  city_pop  \
# 0           0  2291163933867244   2.86  29209  33.9659  -80.9355    333497
# 1           1  3573030041201292  29.84  84002  40.3207 -110.4360       302
# 2           2  3598215285024754  41.28  11710  40.6729  -73.5365     34496
# 3           3  3591919803438423  60.05  32780  28.5697  -80.8191     54767
# 4           4  3526826139003047   3.19  49632  44.2529  -85.0170      1126
#
#       unix_time  merch_lat  merch_long  is_fraud
# 0  1.371817e+09  33.986391  -81.200714       0.0
# 1  1.371817e+09  39.450498 -109.960431       0.0
# 2  1.371817e+09  40.495810  -74.196111       0.0
# 3  1.371817e+09  28.812398  -80.883061       0.0
# 4  1.371817e+09  44.959148  -85.884734       0.0

# %%
outlier_counts = {}
for column, bounds in outlier_bounds.items():
    lower_bound = bounds['Lower Bound']
    upper_bound = bounds['Upper Bound']
    # Count outliers below the lower bound
    lower_outliers = numerical_df[numerical_df[column] < lower_bound][column].count()
    # Count outliers above the upper bound
    upper_outliers = numerical_df[numerical_df[column] > upper_bound][column].count()

    outlier_counts[column] = lower_outliers + upper_outliers

# Print the outlier counts
for column, count in outlier_counts.items():
    print(f"Column: {column}, Outlier Count: {count}")
# Out:
# Column: Unnamed: 0, Outlier Count: 0
# Column: cc_num, Outlier Count: 1041
# Column: amt, Outlier Count: 595
# Column: zip, Outlier Count: 0
# Column: lat, Outlier Count: 38
# Column: long, Outlier Count: 426
# Column: city_pop, Outlier Count: 2191
# Column: unix_time, Outlier Count: 0
# Column: merch_lat, Outlier Count: 38
# Column: merch_long, Outlier Count: 434
# Column: is_fraud, Outlier Count: 29

# %%
df_no_outliers = numerical_df.copy()

for column, bounds in outlier_bounds.items():
    lower_bound = bounds['Lower Bound']
    upper_bound = bounds['Upper Bound']
    df_no_outliers = df_no_outliers[(df_no_outliers[column] >= lower_bound) & (df_no_outliers[column] <= upper_bound)]

print("Shape of DataFrame before outlier removal:", numerical_df.shape)
print("Shape of DataFrame after outlier removal:", df_no_outliers.shape)
# Out:
# Shape of DataFrame before outlier removal: (11696, 11)
# Shape of DataFrame after outlier removal: (7968, 11)

# %%
import matplotlib.pyplot as plt

columns = list(outlier_counts.keys())
counts = list(outlier_counts.values())

plt.figure(figsize=(12, 6))
plt.bar(columns, counts, color='skyblue')
plt.title('Outlier Counts per Numerical Column')
plt.xlabel('Numerical Columns')
plt.ylabel('Number of Outliers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print("Value counts for 'category':")
print(df['category'].value_counts())

plt.figure(figsize=(12, 6))
df['category'].value_counts().head(10).plot(kind='bar', color='lightcoral')
plt.title('Top 10 Most Frequent Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Value counts for 'category':
# category
# home              1211
# kids_pets         1128
# shopping_pos      1069
# gas_transport      952
# personal_care      913
# food_dining        907
# grocery_pos        906
# shopping_net       882
# health_fitness     881
# entertainment      838
# misc_pos           719
# misc_net           535
# travel             414
# grocery_net        341
# Name: count, dtype: int64

# %%
print("Value counts for 'gender':")
print(df['gender'].value_counts())

plt.figure(figsize=(8, 5))
df['gender'].value_counts().plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Value counts for 'gender':
# gender
# F    6483
# M    5213
# Name: count, dtype: int64
